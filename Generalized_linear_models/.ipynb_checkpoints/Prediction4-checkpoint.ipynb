# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
import os
import math
from sklearn.metrics import silhouette_samples,silhouette_score
from sklearn import preprocessing
from scipy.spatial import distance
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
import random 
random.seed(33)
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn import ensemble
from sklearn import linear_model
from sklearn.grid_search import GridSearchCV
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from collections import Counter
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/dsc/anaconda3/lib/python3.5/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
listings = pd.read_csv('../Data/listings_cleanTotal.csv')

# %%
performance2017 = pd.read_excel('../Data/Performance Approach V0.xls')
columns_to_keep = ['id', 'Published_Before_2017', '2017_Total_Income_Est','2017_Total_Number_Reviews']
performance2017 = performance2017[columns_to_keep]

# %%
listingsPerformance = pd.concat([listings, performance2017], axis=1, join='inner')

# %%
#listingsPerformance['avg_nights'] = 4.2
#listingsPerformance['occupancy_est'] = (listingsPerformance['2017_Total_Number_Reviews']/0.7) * (listingsPerformance[['avg_nights', 'minimum_nights']].max(axis=1))
#listingsPerformance['max_occupancy'] = 365 * 0.8

#listingsPerformance['occupancy_est'] = listingsPerformance[['max_occupancy','occupancy_est']].min(axis=1)

# %%
#We remove listings that didn't have performance and have no availability in 2018 as it might mean that they are not really available for booking
listingsPerfClean = listingsPerformance[(listingsPerformance['Published_Before_2017']=='yes') & (listingsPerformance['2017_Total_Number_Reviews']!=0) & (listingsPerformance['availability_365']!=0)]
#listingsPerfClean = listingsPerformance[(listingsPerformance['Published_Before_2017']=='yes')]

# %%
listingsPerfClean.shape
# Out:
# (9058, 48)

# %%
plt.hist(listingsPerfClean['availability_365'])
# Out:
# (array([2345., 1046., 1188.,  666., 1223.,  498.,  625.,  828., 1381.,
#         3242.]),
#  array([  0. ,  36.5,  73. , 109.5, 146. , 182.5, 219. , 255.5, 292. ,
#         328.5, 365. ]),
#  <a list of 10 Patch objects>)

# %%
p95 = np.percentile(listingsPerfClean['availability_365'], 95)
p5 = np.percentile(listingsPerfClean['availability_365'], 5)
listingsPerfClean = listingsPerfClean[(listingsPerfClean['availability_365']<p95)&(listingsPerfClean['availability_365']>p5)]
listingsPerfClean.shape
# Out:
# (11021, 48)

# %%
print(p5, p95)
plt.hist(listingsPerfClean['availability_365'])
# Out:
# 0.0 364.0
# (array([1042., 1066., 1145.,  666., 1215.,  506.,  601.,  776., 1364.,
#         2640.]),
#  array([  1. ,  37.2,  73.4, 109.6, 145.8, 182. , 218.2, 254.4, 290.6,
#         326.8, 363. ]),
#  <a list of 10 Patch objects>)

# %%
listingsPerfClean['neighbourhood_cleansed'].value_counts()
# Out:
# Embajadores         1736
# Universidad         1255
# Palacio              935
# Sol                  842
# Justicia             695
# Cortes               650
# Palos de Moguer      223
# Trafalgar            217
# Goya                 180
# Argüelles            169
# Guindalera           160
# Puerta del Angel     143
# Recoletos            128
# Ibiza                109
# Acacias              108
# Arapiles             103
# Pacífico             102
# Gaztambide            96
# Lista                 95
# Almagro               93
# Delicias              92
# Cuatro Caminos        90
# Castellana            80
# San Isidro            80
# Jerónimos             76
# Chopera               76
# Ventas                73
# Rios Rosas            72
# San Diego             70
# Numancia              65
#                     ...
# Arcos                 11
# Colina                11
# Abrantes              11
# Rosas                 10
# Mirasierra            10
# Salvador              10
# La Paz                 9
# Orcasur                9
# Zofío                  9
# Aguilas                9
# Vinateros              9
# Apostol Santiago       8
# Hellín                 8
# Canillejas             8
# El Goloso              8
# Amposta                7
# Corralejos             7
# San Pascual            5
# Marroquina             5
# Butarque               4
# Aeropuerto             4
# Santa Eugenia          4
# Cuatro Vientos         3
# El Pardo               3
# Pavones                3
# El Plantío             3
# Orcasitas              3
# Ambroz                 3
# Fuentelareina          1
# Atalaya                1
# Name: neighbourhood_cleansed, Length: 126, dtype: int64

# %%
frecuency_prop = listingsPerfClean['property_type'].value_counts()
frecuency_prop
# Out:
# Apartment             9121
# House                  750
# Loft                   246
# Condominium            223
# Other                  168
# Guest suite            154
# Bed & Breakfast        118
# Guesthouse              55
# Vacation home           50
# Chalet                  29
# Dorm                    27
# Casa particular         25
# Serviced apartment      14
# In-law                  12
# Townhouse                9
# Hostel                   9
# Villa                    3
# Camper/RV                2
# Minsu (Taiwan)           1
# Tent                     1
# Earth House              1
# Timeshare                1
# Cave                     1
# Boutique hotel           1
# Name: property_type, dtype: int64

# %%
list_prop = frecuency_prop[frecuency_prop>=100].index
listingsPerfClean['property_type']=np.where(listingsPerfClean['property_type'].isin(list_prop), listingsPerfClean['property_type'], 'Other')
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
listingsPerfClean['property_type'].value_counts()
# Out:
# Apartment          9121
# House               750
# Other               409
# Loft                246
# Condominium         223
# Guest suite         154
# Bed & Breakfast     118
# Name: property_type, dtype: int64

# %%
frecuency_prop = listingsPerfClean['cancellation_policy'].value_counts()
frecuency_prop
# Out:
# strict             4305
# moderate           4002
# flexible           2584
# super_strict_30     130
# Name: cancellation_policy, dtype: int64

# %%
listingsPerfClean['cancellation_policy']=np.where(listingsPerfClean['cancellation_policy'].isin(['strict','super_strict_30']), 'strict', 'flexible')
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
numerical_features = ['latitude', 'longitude', 'accommodates', 'bathrooms','bedrooms', 'minimum_nights',
                      'review_scores_value','price','2017_Total_Number_Reviews']
boolean_features = ['instant_bookable', 'is_business_travel_ready', 'Parking', 'Wifi']
categorical_features = ['property_type', 'cancellation_policy']
listings_categorical = pd.get_dummies(listingsPerfClean[categorical_features], columns=categorical_features, 
                                        prefix=["Property", "CancPol"])
#listingsPerfClean2 = pd.concat([listingsPerfClean['room_type'],listingsPerfClean[numerical_features],
                             #listingsPerfClean[categorical_features],listingsPerfClean[boolean_features]], axis=1)
listingsPerfClean2 = pd.concat([listingsPerfClean['room_type'],listingsPerfClean[numerical_features],
                              listings_categorical,listingsPerfClean[boolean_features]], axis=1)

# %%
listingsHome = listingsPerfClean2[listingsPerfClean2['room_type']=='Entire home/apt'].drop(['room_type'],axis=1)
listingsRoom = listingsPerfClean2[listingsPerfClean2['room_type']=='Private room'].drop(['room_type'],axis=1)
listingsSharedRoom = listingsPerfClean2[listingsPerfClean2['room_type']=='Shared room'].drop(['room_type'],axis=1)

# %%
axs = pd.scatter_matrix(listingsHome[numerical_features],
                        figsize=(12, 12), c='red')
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead

# %% [markdown]
# Accommodates, bathrooms and bedrooms seem to be the only features with a "clear" positive correlation

# %% [markdown]
# We study deeper minimum nights and price, as they seem to have some outliers that are distorting the sample

# %%
listingsHome.describe()
# Out:
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  7576.000000  7576.000000   7576.000000  7576.000000  7576.000000
# mean     40.419757    -3.698594      4.200502     1.254092     1.488912
# std       0.016247     0.018420      1.958596     0.520012     0.965208
# min      40.332586    -3.835498      1.000000     0.000000     0.000000
# 25%      40.410750    -3.707186      3.000000     1.000000     1.000000
# 50%      40.417343    -3.701980      4.000000     1.000000     1.000000
# 75%      40.425243    -3.696167      5.000000     1.000000     2.000000
# max      40.604738    -3.543342     16.000000     6.000000    10.000000
#
#        minimum_nights  review_scores_value        price  \
# count     7576.000000          7576.000000  7576.000000
# mean         2.866684             9.244324    86.903775
# std          9.019417             0.899487    70.654207
# min          1.000000             2.000000    10.000000
# 25%          2.000000             9.000000    55.000000
# 50%          2.000000             9.000000    70.000000
# 75%          3.000000            10.000000    99.000000
# max        365.000000            10.000000  2000.000000
#
#        2017_Total_Number_Reviews  Property_Apartment     ...       \
# count                7576.000000         7576.000000     ...
# mean                   16.257392            0.884768     ...
# std                    21.529263            0.319323     ...
# min                     0.000000            0.000000     ...
# 25%                     1.000000            1.000000     ...
# 50%                     7.000000            1.000000     ...
# 75%                    24.000000            1.000000     ...
# max                   193.000000            1.000000     ...
#
#        Property_Guest suite  Property_House  Property_Loft  Property_Other  \
# count                7576.0     7576.000000    7576.000000     7576.000000
# mean                    0.0        0.041051       0.030227        0.023891
# std                     0.0        0.198421       0.171223        0.152720
# min                     0.0        0.000000       0.000000        0.000000
# 25%                     0.0        0.000000       0.000000        0.000000
# 50%                     0.0        0.000000       0.000000        0.000000
# 75%                     0.0        0.000000       0.000000        0.000000
# max                     0.0        1.000000       1.000000        1.000000
#
#        CancPol_flexible  CancPol_strict  instant_bookable  \
# count       7576.000000     7576.000000       7576.000000
# mean           0.558606        0.441394          0.589097
# std            0.496586        0.496586          0.492030
# min            0.000000        0.000000          0.000000
# 25%            0.000000        0.000000          0.000000
# 50%            1.000000        0.000000          1.000000
# 75%            1.000000        1.000000          1.000000
# max            1.000000        1.000000          1.000000
#
#        is_business_travel_ready      Parking         Wifi
# count               7576.000000  7576.000000  7576.000000
# mean                   0.067054     0.000924     0.966473
# std                    0.250132     0.030385     0.180020
# min                    0.000000     0.000000     0.000000
# 25%                    0.000000     0.000000     1.000000
# 50%                    0.000000     0.000000     1.000000
# 75%                    0.000000     0.000000     1.000000
# max                    1.000000     1.000000     1.000000
#
# [8 rows x 22 columns]

# %%
p98 = np.percentile(listingsHome['minimum_nights'], 98)
listingsHome = listingsHome[listingsHome['minimum_nights']<=p98]
listingsHome.describe()
# Out:
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  7432.000000  7432.000000   7432.000000  7432.000000  7432.000000
# mean     40.419702    -3.698643      4.212056     1.254911     1.488967
# std       0.016134     0.018286      1.964008     0.521160     0.967588
# min      40.332586    -3.835498      1.000000     0.000000     0.000000
# 25%      40.410756    -3.707182      3.000000     1.000000     1.000000
# 50%      40.417203    -3.701990      4.000000     1.000000     1.000000
# 75%      40.425145    -3.696278      5.000000     1.000000     2.000000
# max      40.604738    -3.543342     16.000000     6.000000    10.000000
#
#        minimum_nights  review_scores_value        price  \
# count     7432.000000          7432.000000  7432.000000
# mean         2.274085             9.246233    87.002018
# std          1.138899             0.891609    70.795570
# min          1.000000             2.000000    10.000000
# 25%          2.000000             9.000000    55.000000
# 50%          2.000000             9.000000    71.000000
# 75%          3.000000            10.000000    99.000000
# max          7.000000            10.000000  2000.000000
#
#        2017_Total_Number_Reviews  Property_Apartment     ...       \
# count                7432.000000         7432.000000     ...
# mean                   16.265205            0.883611     ...
# std                    21.557159            0.320712     ...
# min                     0.000000            0.000000     ...
# 25%                     1.000000            1.000000     ...
# 50%                     7.000000            1.000000     ...
# 75%                    24.000000            1.000000     ...
# max                   193.000000            1.000000     ...
#
#        Property_Guest suite  Property_House  Property_Loft  Property_Other  \
# count                7432.0     7432.000000    7432.000000     7432.000000
# mean                    0.0        0.041308       0.030544        0.024220
# std                     0.0        0.199015       0.172089        0.153741
# min                     0.0        0.000000       0.000000        0.000000
# 25%                     0.0        0.000000       0.000000        0.000000
# 50%                     0.0        0.000000       0.000000        0.000000
# 75%                     0.0        0.000000       0.000000        0.000000
# max                     0.0        1.000000       1.000000        1.000000
#
#        CancPol_flexible  CancPol_strict  instant_bookable  \
# count       7432.000000     7432.000000       7432.000000
# mean           0.559742        0.440258          0.596475
# std            0.496452        0.496452          0.490637
# min            0.000000        0.000000          0.000000
# 25%            0.000000        0.000000          0.000000
# 50%            1.000000        0.000000          1.000000
# 75%            1.000000        1.000000          1.000000
# max            1.000000        1.000000          1.000000
#
#        is_business_travel_ready      Parking         Wifi
# count               7432.000000  7432.000000  7432.000000
# mean                   0.067815     0.000942     0.966362
# std                    0.251445     0.030678     0.180309
# min                    0.000000     0.000000     0.000000
# 25%                    0.000000     0.000000     1.000000
# 50%                    0.000000     0.000000     1.000000
# 75%                    0.000000     0.000000     1.000000
# max                    1.000000     1.000000     1.000000
#
# [8 rows x 22 columns]

# %%
p98 = np.percentile(listingsHome['price'], 98)
listingsHome = listingsHome[listingsHome['price']<=p98]
listingsHome.describe()
# Out:
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  5957.000000  5957.000000   5957.000000  5957.000000  5957.000000
# mean     40.419882    -3.698651      4.126070     1.231828     1.453416
# std       0.016260     0.018447      1.783361     0.464008     0.902605
# min      40.332908    -3.835498      1.000000     0.000000     0.000000
# 25%      40.410754    -3.707181      3.000000     1.000000     1.000000
# 50%      40.417415    -3.701962      4.000000     1.000000     1.000000
# 75%      40.425309    -3.696236      5.000000     1.000000     2.000000
# max      40.511100    -3.543342     16.000000     5.500000    10.000000
#
#        minimum_nights  review_scores_value        price  \
# count     5957.000000          5957.000000  5957.000000
# mean         2.971462             9.221252    81.861004
# std         10.948327             0.929914    37.276500
# min          1.000000             2.000000    10.000000
# 25%          2.000000             9.000000    55.000000
# 50%          2.000000             9.000000    71.000000
# 75%          3.000000            10.000000    99.000000
# max        500.000000            10.000000   247.000000
#
#        2017_Total_Number_Reviews  Property_Apartment     ...       \
# count                5957.000000         5957.000000     ...
# mean                   21.145039            0.887024     ...
# std                    22.350348            0.316590     ...
# min                     1.000000            0.000000     ...
# 25%                     4.000000            1.000000     ...
# 50%                    13.000000            1.000000     ...
# 75%                    31.000000            1.000000     ...
# max                   193.000000            1.000000     ...
#
#        Property_Vacation home  Property_Villa  CancPol_flexible  \
# count             5957.000000     5957.000000       5957.000000
# mean                 0.006043        0.000336          0.180292
# std                  0.077510        0.018322          0.384463
# min                  0.000000        0.000000          0.000000
# 25%                  0.000000        0.000000          0.000000
# 50%                  0.000000        0.000000          0.000000
# 75%                  0.000000        0.000000          0.000000
# max                  1.000000        1.000000          1.000000
#
#        CancPol_moderate  CancPol_strict  CancPol_super_strict_30  \
# count       5957.000000     5957.000000              5957.000000
# mean           0.374685        0.426557                 0.018466
# std            0.484082        0.494618                 0.134639
# min            0.000000        0.000000                 0.000000
# 25%            0.000000        0.000000                 0.000000
# 50%            0.000000        0.000000                 0.000000
# 75%            1.000000        1.000000                 0.000000
# max            1.000000        1.000000                 1.000000
#
#        instant_bookable  is_business_travel_ready      Parking         Wifi
# count       5957.000000               5957.000000  5957.000000  5957.000000
# mean           0.578983                  0.065469     0.000504     0.966426
# std            0.493764                  0.247373     0.022437     0.180145
# min            0.000000                  0.000000     0.000000     0.000000
# 25%            0.000000                  0.000000     0.000000     1.000000
# 50%            1.000000                  0.000000     0.000000     1.000000
# 75%            1.000000                  0.000000     0.000000     1.000000
# max            1.000000                  1.000000     1.000000     1.000000
#
# [8 rows x 41 columns]

# %%
listingsHome = listingsHome[listingsHome['accommodates']<=10]
listingsHome.describe()
# Out:
#           latitude    longitude  accommodates    bathrooms    bedrooms  \
# count  5915.000000  5915.000000   5915.000000  5915.000000  5915.00000
# mean     40.419902    -3.698633      4.067287     1.224345     1.43415
# std       0.016276     0.018409      1.643447     0.452662     0.86930
# min      40.332908    -3.835498      1.000000     0.000000     0.00000
# 25%      40.410749    -3.707153      3.000000     1.000000     1.00000
# 50%      40.417458    -3.701957      4.000000     1.000000     1.00000
# 75%      40.425337    -3.696166      5.000000     1.000000     2.00000
# max      40.511100    -3.543342     10.000000     4.000000     5.00000
#
#        minimum_nights  review_scores_value        price  \
# count     5915.000000          5915.000000  5915.000000
# mean         2.978698             9.222147    81.404565
# std         10.986552             0.931551    36.793579
# min          1.000000             2.000000    10.000000
# 25%          2.000000             9.000000    55.000000
# 50%          2.000000             9.000000    70.000000
# 75%          3.000000            10.000000    98.000000
# max        500.000000            10.000000   247.000000
#
#        2017_Total_Number_Reviews  Property_Apartment     ...       \
# count                5915.000000         5915.000000     ...
# mean                   21.133728            0.888419     ...
# std                    22.331976            0.314877     ...
# min                     1.000000            0.000000     ...
# 25%                     4.000000            1.000000     ...
# 50%                    13.000000            1.000000     ...
# 75%                    31.000000            1.000000     ...
# max                   193.000000            1.000000     ...
#
#        Property_Vacation home  Property_Villa  CancPol_flexible  \
# count             5915.000000     5915.000000       5915.000000
# mean                 0.005579        0.000169          0.181234
# std                  0.074491        0.013002          0.385245
# min                  0.000000        0.000000          0.000000
# 25%                  0.000000        0.000000          0.000000
# 50%                  0.000000        0.000000          0.000000
# 75%                  0.000000        0.000000          0.000000
# max                  1.000000        1.000000          1.000000
#
#        CancPol_moderate  CancPol_strict  CancPol_super_strict_30  \
# count       5915.000000     5915.000000              5915.000000
# mean           0.374134        0.426036                 0.018597
# std            0.483939        0.494541                 0.135107
# min            0.000000        0.000000                 0.000000
# 25%            0.000000        0.000000                 0.000000
# 50%            0.000000        0.000000                 0.000000
# 75%            1.000000        1.000000                 0.000000
# max            1.000000        1.000000                 1.000000
#
#        instant_bookable  is_business_travel_ready      Parking         Wifi
# count       5915.000000               5915.000000  5915.000000  5915.000000
# mean           0.578529                  0.065427     0.000507     0.966188
# std            0.493836                  0.247298     0.022517     0.180761
# min            0.000000                  0.000000     0.000000     0.000000
# 25%            0.000000                  0.000000     0.000000     1.000000
# 50%            1.000000                  0.000000     0.000000     1.000000
# 75%            1.000000                  0.000000     0.000000     1.000000
# max            1.000000                  1.000000     1.000000     1.000000
#
# [8 rows x 41 columns]

# %%
axs = pd.scatter_matrix(listingsHome[numerical_features],
                        figsize=(12, 12), c='red')
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead

# %%
X = listingsHome.loc[:,listingsHome.columns != '2017_Total_Number_Reviews']
y = listingsHome['2017_Total_Number_Reviews']
y = y.reshape(-1,1)
# Out:
# /home/dsc/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X.columns
# Out:
# Index(['price', 'review_scores_value', 'accommodates', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.25,
                            random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4436, 5)
# (1479, 5)
# (4436, 1)
# (1479, 1)

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

scalerX = StandardScaler().fit(X_train)
scalery = StandardScaler().fit(y_train)
X_train = scalerX.transform(X_train)
y_train = scalery.transform(y_train)
X_test = scalerX.transform(X_test)
y_test = scalery.transform(y_test)

# %%
cov_X = np.cov(X_train.T) # Construct the covariance matrix.
eigen_vals, eigen_vecs = np.linalg.eig(cov_X) #Decompose the covariance matrix into its eigenvectors and eigenvalues.

import matplotlib.pyplot as plt
sorted_eigen_vals = sorted(eigen_vals, reverse = True)
tot = sum(eigen_vals)
var_exp = [(i/tot) for i in sorted_eigen_vals]
cum_var_exp = np.cumsum(var_exp)
plt.bar(range(1,len(var_exp)+1), var_exp, alpha = 0.5, align = 'center',
        label = 'Individual Explained Variance')
plt.step(range(1,len(var_exp)+1), cum_var_exp, where='mid',
        label = 'Cumulative Explained Variance')
plt.ylabel('Explained Variance Ratio')
plt.xlabel('Principal Components')
plt.legend(loc='best')
plt.show()
pca = []
for i in range(0,20:
    #print(str(i+1) + ' principal component is:' + str(X.columns.values[np.where(eigen_vals==sorted_eigen_vals[i])]))
    pca.extend(X.columns.values[np.where(eigen_vals==sorted_eigen_vals[i])])
print(pca)
X = X[pca]
# Out:
# ['price', 'review_scores_value', 'accommodates', 'longitude', 'latitude']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.25,
                            random_state=0)
scalerX = StandardScaler().fit(X_train)
scalery = StandardScaler().fit(y_train)
X_train = scalerX.transform(X_train)
y_train = scalery.transform(y_train)
X_test = scalerX.transform(X_test)
y_test = scalery.transform(y_test)

# %%
print(np.max(y_train), np.min(y_train), np.mean(y_train))
print(np.max(y_test), np.min(y_test), np.mean(y_test))
# Out:
# 7.677420653221327 -0.8993780081066411 3.764146593859864e-17
# 4.773816939750922 -0.8993780081066411 4.899541377521996e-05

# %%
def train_and_validate(method_name, slr, X_train,y_train, X_test, y_test):
    slr.fit(X_train,y_train)
    y_train_pred = slr.predict(X_train)
    mse_train = mean_squared_error(y_train, y_train_pred)
    r2_train = r2_score(y_train, y_train_pred)
    y_test_pred = slr.predict(X_test)
    mse_test = mean_squared_error(y_test, y_test_pred)
    r2_test = r2_score(y_test, y_test_pred)
    
    print('Method: %s' %method_name)
    print('MSE on training: %.3f' %mse_train)
    print('r^2 on training: %.3f' %r2_train)
    print('MSE on test: %.3f' %mse_test)
    print('r^2 on test: %.3f' %r2_test)
    
    return y_test_pred

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.cross_validation import cross_val_score, KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# Compute MSE on training data
sgdreg = SGDRegressor(loss='squared_loss', penalty=None,  random_state=10)

method_name = 'Stochastic Gradient Descent Regression'
y_test_pred = train_and_validate(method_name, sgdreg, X_train,y_train, X_test, y_test)
# Out:
# Method: Stochastic Gradient Descent Regression
# MSE on training: 1.000
# r^2 on training: 0.000
# MSE on test: 0.982
# r^2 on test: -0.002

# %%
from sklearn.linear_model import ElasticNet
enet = ElasticNet(alpha=0.05, l1_ratio=0.1)
y_test_pred = train_and_validate("Elastic Net", enet, X_train,y_train, X_test, y_test)
# Out:
# Method: Elastic Net
# MSE on training: 0.999
# r^2 on training: 0.001
# MSE on test: 0.981
# r^2 on test: -0.001

# %%
from sklearn import svm
slr_svr = svm.SVR(kernel='linear')
y_test_pred = train_and_validate("Support Vector Machine", slr_svr, X_train,y_train, X_test, y_test)
# Out:
# Method: Support Vector Machine
# MSE on training: 1.129
# r^2 on training: -0.129
# MSE on test: 1.114
# r^2 on test: -0.136

# %%
from sklearn.svm import SVR
slr_svr_rbf_1 = SVR(kernel='rbf', C=1)
y_test_pred_1 = train_and_validate("Support Vector Machine RBF", slr_svr_rbf_1, X_train,y_train, X_test, y_test)
slr_svr_rbf_2 = SVR(kernel='rbf', C=10)
y_test_pred_2 = train_and_validate("Support Vector Machine RBF", slr_svr_rbf_2, X_train,y_train, X_test, y_test)
# Out:
# Method: Support Vector Machine RBF
# MSE on training: 1.083
# r^2 on training: -0.083
# MSE on test: 1.104
# r^2 on test: -0.127
# Method: Support Vector Machine RBF
# MSE on training: 1.045
# r^2 on training: -0.045
# MSE on test: 1.131
# r^2 on test: -0.154

# %%
lw = 2
plt.scatter(range(0, 100), y_test[0:100], color='darkorange', label='data')
plt.hold('on')
plt.plot(range(0, 100), y_test_pred_1[0:100], color='b',label='RBF model C 1')
plt.plot(range(0, 100), y_test_pred_2[0:100], color='g',label='RBF model C 10')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(20, 10)
plt.show()

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(hidden_layer_sizes=(50,10,), max_iter=1000, learning_rate = 'adaptive')
y_test_pred = train_and_validate("Multi-layer Perceptron regressor", mlp, X_train,y_train, X_test, y_test)
# Out:
# Method: Multi-layer Perceptron regressor
# MSE on training: 0.977
# r^2 on training: 0.023
# MSE on test: 0.993
# r^2 on test: -0.013

# %%
from sklearn.ensemble import GradientBoostingRegressor
params = {'n_estimators': 180, 
          'max_depth': 1, 
          'min_samples_split': 2,
          'learning_rate': 0.2, 
          'loss': 'ls'}
gbr = GradientBoostingRegressor(**params)

gbr.fit(X_train, y_train)
y_pred_gbr = train_and_validate("forward stage-wise", gbr, X_train,y_train, X_test, y_test)
# Out:
# Method: forward stage-wise
# MSE on training: 0.977
# r^2 on training: 0.023
# MSE on test: 0.985
# r^2 on test: -0.005

# %%
# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(gbr.staged_predict(X_test)):
    test_score[i] = gbr.loss_(y_test, y_pred)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, gbr.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')
plt.show()

# %%
feature_importance = gbr.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
fig = plt.gcf()
fig.set_size_inches(20, 18)
plt.show()

# %%
print(__doc__)

# Author: Noel Dawe <noel.dawe@gmail.com>
#
# License: BSD 3 clause

# importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor


# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=10),
                          n_estimators=2000, random_state=0)

regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

# Predict
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(range(0,100), y_test[0:100], c="k", label="training samples")
plt.plot(range(0,100), y_1[0:100], c="g", label="n_estimators=1", linewidth=1)
plt.plot(range(0,100), y_2[0:100], c="r", label="n_estimators=2000", linewidth=1)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Boosted Decision Tree Regression")
plt.legend()
fig = plt.gcf()
fig.set_size_inches(20, 10)
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
pred = train_and_validate("Decision Tree Regressor", regr_1, X_train,y_train, X_test, y_test)
# Out:
# Method: Decision Tree Regressor
# MSE on training: 0.983
# r^2 on training: 0.017
# MSE on test: 1.009
# r^2 on test: -0.014

# %%
pred = train_and_validate("AdaBoost DTR", regr_2, X_train,y_train, X_test, y_test)
# Out:
# Method: AdaBoost DTR
# MSE on training: 0.921
# r^2 on training: 0.079
# MSE on test: 1.425
# r^2 on test: -0.432
