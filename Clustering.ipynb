# %% [markdown]
# # Preparing data for clustering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
import os
import math

# %%
listings = pd.read_csv('./Data/listings_clean.csv', index_col=0)

# %%
listings.head()
# Out:
#         latitude  longitude  host_response_rate  host_listings_count  \
# id
# 18628  40.424715  -3.698638                0.60                  1.0
# 19864  40.413418  -3.706838                1.00                  1.0
# 21512  40.424920  -3.713446                1.00                 12.0
# 23021  40.423417  -3.712456                1.00                 12.0
# 24805  40.422022  -3.703954                0.83                  3.0
#
#        accommodates  bathrooms  bedrooms  beds  price  security_deposit  \
# id
# 18628             2        1.0       0.0   1.0   54.0             100.0
# 19864             2        1.0       0.0   1.0   65.0             250.0
# 21512             2        1.0       0.0   1.0   40.0             100.0
# 23021            10        3.0       4.0   5.0   90.0             300.0
# 24805             3        1.0       0.0   2.0   55.0             200.0
#
#                  ...             Amen_Wireless Internet  host_is_superhost  \
# id               ...
# 18628            ...                                  1                  0
# 19864            ...                                  1                  0
# 21512            ...                                  1                  0
# 23021            ...                                  1                  0
# 24805            ...                                  1                  0
#
#        host_identity_verified  host_has_profile_pic  instant_bookable  \
# id
# 18628                       0                     1                 1
# 19864                       1                     1                 1
# 21512                       0                     1                 0
# 23021                       0                     1                 0
# 24805                       1                     1                 0
#
#        require_guest_profile_picture  require_guest_phone_verification  \
# id
# 18628                              0                                 0
# 19864                              0                                 0
# 21512                              0                                 0
# 23021                              0                                 0
# 24805                              0                                 0
#
#        weekly_price  monthly_price  is_business_travel_ready
# id
# 18628             1              1                         0
# 19864             0              1                         0
# 21512             1              1                         0
# 23021             1              1                         0
# 24805             1              1                         0
#
# [5 rows x 150 columns]

# %%
listings.columns[:]
# Out:
# Index(['latitude', 'longitude', 'host_response_rate', 'host_listings_count',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'security_deposit',
#        ...
#        'Amen_Wireless Internet', 'host_is_superhost', 'host_identity_verified',
#        'host_has_profile_pic', 'instant_bookable',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'weekly_price', 'monthly_price', 'is_business_travel_ready'],
#       dtype='object', length=150)

# %%
for_cluster = ['latitude', 'longitude', 'accommodates', 'bathrooms','bedrooms', 'beds', 'instant_bookable',
              'is_business_travel_ready']

# %%
reviewScoresColums = listings.filter(regex='review_scores.*').columns
for_cluster.extend(reviewScoresColums)

# %%
AmenColums = listings.filter(regex='Amen_.*').columns
for_cluster.extend(AmenColums)

# %%
categorical_features = ['neighbourhood_cleansed', 'property_type', 'bed_type']
listings_categorical = pd.get_dummies(listings[categorical_features], columns=categorical_features, 
                            prefix=["Neigh", "Property", "Bed"])

# %%
listingsCluster = pd.concat([listings[for_cluster], listings_categorical], axis=1)
listingsCluster.head()
# Out:
#         latitude  longitude  accommodates  bathrooms  bedrooms  beds  \
# id
# 18628  40.424715  -3.698638             2        1.0       0.0   1.0
# 19864  40.413418  -3.706838             2        1.0       0.0   1.0
# 21512  40.424920  -3.713446             2        1.0       0.0   1.0
# 23021  40.423417  -3.712456            10        3.0       4.0   5.0
# 24805  40.422022  -3.703954             3        1.0       0.0   2.0
#
#        instant_bookable  is_business_travel_ready  review_scores_rating  \
# id
# 18628                 1                         0                  89.0
# 19864                 1                         0                  91.0
# 21512                 0                         0                  79.0
# 23021                 0                         0                  80.0
# 24805                 0                         0                 100.0
#
#        review_scores_accuracy      ...       Property_Other  \
# id                                 ...
# 18628                     9.0      ...                    0
# 19864                     9.0      ...                    0
# 21512                     9.0      ...                    0
# 23021                     8.0      ...                    0
# 24805                     8.0      ...                    0
#
#        Property_Serviced apartment  Property_Townhouse  \
# id
# 18628                            0                   0
# 19864                            0                   0
# 21512                            0                   0
# 23021                            0                   0
# 24805                            0                   0
#
#        Property_Vacation home  Property_Villa  Bed_Airbed  Bed_Couch  \
# id
# 18628                       0               0           0          0
# 19864                       0               0           0          0
# 21512                       0               0           0          0
# 23021                       0               0           0          0
# 24805                       0               0           0          0
#
#        Bed_Futon  Bed_Pull-out Sofa  Bed_Real Bed
# id
# 18628          0                  1             0
# 19864          0                  1             0
# 21512          0                  1             0
# 23021          0                  0             1
# 24805          0                  0             1
#
# [5 rows x 266 columns]

# %%
# %pylab inline
import pandas as pd
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from sklearn.manifold import TSNE
tsne5 = TSNE(n_components=2, perplexity=5)
X_enc5 =tsne5.fit_transform(listingsCluster)
tsne10 = TSNE(n_components=2, perplexity=10)
X_enc10 =tsne10.fit_transform(listingsCluster)
tsne30 = TSNE(n_components=2, perplexity=30)
X_enc30 =tsne30.fit_transform(listingsCluster)
tsne50 = TSNE(n_components=2, perplexity=50)
X_enc50 =tsne50.fit_transform(listingsCluster)
tsne100 = TSNE(n_components=2, perplexity=100)
X_enc100 =tsne100.fit_transform(listingsCluster)
tsne200 = TSNE(n_components=2, perplexity=200)
X_enc200 =tsne200.fit_transform(listingsCluster)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-117bd1642c94> in <module>()
#      11 X_enc100 =tsne100.fit_transform(listingsCluster)
#      12 tsne200 = TSNE(n_components=2, perplexity=200)
# ---> 13 X_enc200 =tsne200.fit_transform(listingsCluster)
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     856             Embedding of the training data in low-dimensional space.
#     857         """
# --> 858         embedding = self._fit(X)
#     859         self.embedding_ = embedding
#     860         return self.embedding_
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     768                           X_embedded=X_embedded,
#     769                           neighbors=neighbors_nn,
# --> 770                           skip_num_points=skip_num_points)
#     771
#     772     @property
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#     825             opt_args['n_iter_without_progress'] = self.n_iter_without_progress
#     826             params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 827                                                           **opt_args)
#     828
#     829         # Save the final number of iterations
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     337     tic = time()
#     338     for i in range(it, n_iter):
# --> 339         error, grad = objective(p, *args, **kwargs)
#     340         grad_norm = linalg.norm(grad)
#     341
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose)
#     245     error = _barnes_hut_tsne.gradient(val_P, X_embedded, neighbors, indptr,
#     246                                       grad, angle, n_components, verbose,
# --> 247                                       dof=degrees_of_freedom)
#     248     c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     249     grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
py.iplot([go.Scatter(x=X_enc[:,0],y=X_enc[:,1], mode='markers', marker=dict(size=2))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ac57bf094e02> in <module>()
# ----> 1 py.iplot([go.Scatter(x=X_enc[:,0],y=X_enc[:,1], mode='markers', marker=dict(size=2))])
#
# NameError: name 'X_enc' is not defined
